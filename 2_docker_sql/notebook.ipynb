# %%
import pandas as pd

# %%
import pandas as pd

# Membaca file Parquet
df = pd.read_parquet("yellow_tripdata_2024-01.parquet", engine="pyarrow", nrows=100)  # atau "fastparquet"

# Menampilkan beberapa baris pertama
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 # Membaca file Parquet
# ----> 4 df = pd.read_parquet("yellow_tripdata_2024-01.parquet", engine="pyarrow", nrows=100)  # atau "fastparquet"
#       6 # Menampilkan beberapa baris pertama
#       7 print(df.head())
#
# File c:\Users\rozak\Downloads\projects\my-data-engineering-zoomcamp\.venv\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File c:\Users\rozak\Downloads\projects\my-data-engineering-zoomcamp\.venv\Lib\site-packages\pandas\io\parquet.py:274, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
# --> 274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#     277         filesystem=filesystem,
#     278         filters=filters,
#     279         **kwargs,
#     280     )
#     281     result = pa_table.to_pandas(**to_pandas_kwargs)
#     283     if manager == "array":
#
# TypeError: read_table() got an unexpected keyword argument 'nrows'

# %%
df.to_csv("yellow_tripdata_2024-01.csv", index=False)

print("Konversi berhasil! File CSV telah disimpan.")
# Out:
# Konversi berhasil! File CSV telah disimpan.

# %%
df = pd.read_csv('yellow_tripdata_2024-01.csv',nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1          1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2          1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3          1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4          1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ..       ...                  ...                   ...              ...
# 95         2  2024-01-01 00:54:16   2024-01-01 01:27:40              1.0
# 96         2  2024-01-01 00:13:58   2024-01-01 00:33:39              1.0
# 97         2  2024-01-01 00:35:53   2024-01-01 00:47:59              1.0
# 98         2  2024-01-01 00:50:28   2024-01-01 01:38:39              1.0
# 99         2  2024-01-01 00:18:24   2024-01-01 00:30:39              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.72         1.0                  N           186            79
# 1            1.80         1.0                  N           140           236
# 2            4.70         1.0                  N           236            79
# 3            1.40         1.0                  N            79           211
# 4            0.80         1.0                  N           211           148
# ..            ...         ...                ...           ...           ...
# 95          13.74         1.0                  N           239            95
# 96           4.20         1.0                  N           148           237
# 97           1.14         1.0                  N           237           233
# 98          20.34         1.0                  N           132            26
# 99           2.16         1.0                  N           249           232
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              2         17.7    1.0      0.5        0.00          0.00
# 1              1         10.0    3.5      0.5        3.75          0.00
# 2              1         23.3    3.5      0.5        3.00          0.00
# 3              1         10.0    3.5      0.5        2.00          0.00
# 4              1          7.9    3.5      0.5        3.20          0.00
# ..           ...          ...    ...      ...         ...           ...
# 95             1         56.9    1.0      0.5       13.77          6.94
# 96             1         21.9    1.0      0.5        5.38          0.00
# 97             1         11.4    1.0      0.5        3.28          0.00
# 98             1         80.0    1.0      0.5        2.00          0.00
# 99             4        -13.5   -1.0     -0.5        0.00          0.00
#
#     improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                     1.0         22.70                   2.5         0.00
# 1                     1.0         18.75                   2.5         0.00
# 2                     1.0         31.30                   2.5         0.00
# 3                     1.0         17.00                   2.5         0.00
# 4                     1.0         16.10                   2.5         0.00
# ..                    ...           ...                   ...          ...
# 95                    1.0         82.61                   2.5         0.00
# 96                    1.0         32.28                   2.5         0.00
# 97                    1.0         19.68                   2.5         0.00
# 98                    1.0         86.25                   0.0         1.75
# 99                   -1.0        -18.50                  -2.5         0.00
#
# [100 rows x 19 columns]

# %%
print(pd.io.sql.get_schema(df,name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "Airport_fee" REAL
# )
